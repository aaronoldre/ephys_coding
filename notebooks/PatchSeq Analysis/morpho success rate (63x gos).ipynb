# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#load all the data

df_mouse = pd.read_excel('Patch-seq log.xlsx','Mouse PatchSeq')
#df_human = pd.read_excel('Patch-seq log.xlsx','Human PatchSeq')

# %%
sns.set_style('whitegrid')

temp1 = df_mouse[df_mouse['patch duration'].notnull()]
#temp = temp[temp['Depth (um)'].notnull()]
temp1 = temp1[temp1['63x go no go'].notnull()]
temp1 = temp1[temp1['Post patch pipette R'].notnull()]

temp = temp1[temp1['63x go no go'] == '63x go']

values, base = np.histogram(temp['patch duration'], bins = 50)
cumulative = np.cumsum(values)/float(len(temp))
plt.plot(base[:-1]*60, cumulative, c='green')

temp = temp1[temp1['63x go no go'] == '63x no go']
print len(temp)

values, base = np.histogram(temp['patch duration'], bins = 50)
cumulative = np.cumsum(values)/float(len(temp))
plt.plot(base[:-1]*60, cumulative, c='red')

plt.xlabel('Patch Duration (sec)')
plt.ylabel('Cumulative Probability')
# Out:
# 115

# %%
temp = temp1[temp1['63x go no go'] == '63x go']

values, base = np.histogram(temp['Post patch pipette R'], bins = 50)
cumulative = np.cumsum(values)/float(len(temp))
plt.plot(base[:-1], cumulative, c='green')

temp = temp1[temp1['63x go no go'] == '63x no go']
print len(temp)

values, base = np.histogram(temp['Post patch pipette R'], bins = 50)
cumulative = np.cumsum(values)/float(len(temp))
plt.plot(base[:-1], cumulative, c='red')

plt.xlabel('Post Patch Pipette Resistance (MOhm)')
plt.ylabel('Cumulative Probability')
# Out:
# 115

# %%
df_mouse['63x go no go'].unique()
# Out:
# array([nan, u'63x go', u'63x no go'], dtype=object)

# %%
sns.set_style('white')
sns.lmplot(x = 'patch duration', y = 'Post patch pipette R',
            hue = 'Post patch?', col = '63x go no go', 
           data = temp1, fit_reg = False)

# %%
sns.boxplot(x = '63x go no go', y = 'patch duration', data = temp1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-4826342a4b73> in <module>()
# ----> 1 sns.boxplot(x = '63x go no go', y = 'patch duration', data = temp1)
#
# C:\Users\aarono\AppData\Local\Continuum\anaconda2\lib\site-packages\seaborn\categorical.pyc in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2196     kwargs.update(dict(whis=whis, notch=notch))
#    2197
# -> 2198     plotter.plot(ax, kwargs)
#    2199     return ax
#    2200
#
# C:\Users\aarono\AppData\Local\Continuum\anaconda2\lib\site-packages\seaborn\categorical.pyc in plot(self, ax, boxplot_kws)
#     534     def plot(self, ax, boxplot_kws):
#     535         """Make the plot."""
# --> 536         self.draw_boxplot(ax, boxplot_kws)
#     537         self.annotate_axes(ax)
# ...
