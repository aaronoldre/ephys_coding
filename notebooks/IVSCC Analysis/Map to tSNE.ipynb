# %% [markdown]
# #### We want to access all the cells in LIMS that have failed due to input resistance and map them back to Nathan's tSNE plot.
#
# 1. What cells are we searching for in LIMS?
# 2. What is needed to fit into tSNE?
# 3. Do I want features for LIMS or file paths?

# %%
import pg8000
import pandas as pd

# %%
#code from Agata

def _connect(user="limsreader", host="limsdb2", database="lims2", password="limsro", port=5432):
    conn = pg8000.connect(user=user, host=host, database=database, password=password, port=port)
    return conn, conn.cursor()

def _select(cursor, query):
    cursor.execute(query)
    columns = [ d[0] for d in cursor.description ]
    return [ dict(zip(columns, c)) for c in cursor.fetchall() ]

def limsquery(query, user="limsreader", host="limsdb2", database="lims2", password="limsro", port=5432):
    """A function that takes a string containing a SQL query, connects to the LIMS database and outputs the result."""
    conn, cursor = _connect(user, host, database, password, port)
    try:
        results = _select(cursor, query)
    finally:
        cursor.close()
        conn.close()
    return results

# %% [markdown]
# ### What are the elements named in LIMS?
# #### This is an easy way to search through the tables in LIMS to find out what columns are called

# %%
my_query = "SELECT TABLE_NAME FROM INFORMATION_SCHEMA.TABLES"
my_result = limsquery(my_query)
#first_element = my_result[0]
#print sorted(first_element.keys())

# %%
my_result
# Out:
# [{'table_name': u'pg_type'},
#  {'table_name': u'pg_roles'},
#  {'table_name': u'pg_group'},
#  {'table_name': u'pg_user'},
#  {'table_name': u'pg_rules'},
#  {'table_name': u'pg_views'},
#  {'table_name': u'pg_tables'},
#  {'table_name': u'pg_matviews'},
#  {'table_name': u'pg_indexes'},
#  {'table_name': u'pg_stats'},
#  {'table_name': u'pg_settings'},
#  {'table_name': u'pg_locks'},
#  {'table_name': u'pg_cursors'},
#  {'table_name': u'pg_available_extensions'},
#  {'table_name': u'pg_available_extension_versions'},
#  {'table_name': u'pg_prepared_xacts'},
#  {'table_name': u'pg_prepared_statements'},
#  {'table_name': u'pg_seclabels'},
#  {'table_name': u'pg_timezone_abbrevs'},
#  {'table_name': u'pg_timezone_names'},
#  {'table_name': u'pg_stat_all_tables'},
#  {'table_name': u'pg_stat_xact_all_tables'},
#  {'table_name': u'pg_stat_sys_tables'},
#  {'table_name': u'pg_stat_xact_sys_tables'},
#  {'table_name': u'pg_stat_user_tables'},
#  {'table_name': u'pg_stat_xact_user_tables'},
#  {'table_name': u'pg_statio_all_tables'},
#  {'table_name': u'pg_statio_sys_tables'},
#  {'table_name': u'pg_statio_user_tables'},
#  {'table_name': u'pg_statio_all_indexes'},
#  {'table_name': u'pg_statio_sys_indexes'},
#  {'table_name': u'pg_statio_user_indexes'},
#  {'table_name': u'pg_statio_all_sequences'},
#  {'table_name': u'pg_statio_sys_sequences'},
#  {'table_name': u'pg_statio_user_sequences'},
#  {'table_name': u'pg_stat_activity'},
#  {'table_name': u'pg_stat_replication'},
#  {'table_name': u'pg_replication_slots'},
#  {'table_name': u'pg_stat_database'},
#  {'table_name': u'pg_stat_database_conflicts'},
#  {'table_name': u'pg_stat_user_functions'},
#  {'table_name': u'pg_stat_xact_user_functions'},
#  {'table_name': u'pg_stat_archiver'},
#  {'table_name': u'pg_stat_bgwriter'},
#  {'table_name': u'pg_user_mappings'},
#  {'table_name': u'animal_monitoring_details'},
#  {'table_name': u'pg_stat_all_indexes'},
#  {'table_name': u'pg_stat_sys_indexes'},
#  {'table_name': u'pg_stat_user_indexes'},
#  {'table_name': u'information_schema_catalog_name'},
#  {'table_name': u'applicable_roles'},
#  {'table_name': u'administrable_role_authorizations'},
#  {'table_name': u'attributes'},
#  {'table_name': u'character_sets'},
#  {'table_name': u'check_constraint_routine_usage'},
#  {'table_name': u'check_constraints'},
#  {'table_name': u'collations'},
#  {'table_name': u'collation_character_set_applicability'},
#  {'table_name': u'column_domain_usage'},
#  {'table_name': u'column_privileges'},
#  {'table_name': u'column_udt_usage'},
#  {'table_name': u'columns'},
#  {'table_name': u'constraint_column_usage'},
#  {'table_name': u'constraint_table_usage'},
#  {'table_name': u'domain_constraints'},
#  {'table_name': u'domain_udt_usage'},
#  {'table_name': u'domains'},
#  {'table_name': u'enabled_roles'},
#  {'table_name': u'key_column_usage'},
#  {'table_name': u'parameters'},
#  {'table_name': u'referential_constraints'},
#  {'table_name': u'role_column_grants'},
#  {'table_name': u'routine_privileges'},
#  {'table_name': u'role_routine_grants'},
#  {'table_name': u'routines'},
#  {'table_name': u'schemata'},
#  {'table_name': u'sequences'},
#  {'table_name': u'pg_attribute'},
#  {'table_name': u'pg_proc'},
#  {'table_name': u'table_constraints'},
#  {'table_name': u'table_privileges'},
#  {'table_name': u'role_table_grants'},
#  {'table_name': u'tables'},
#  {'table_name': u'triggered_update_columns'},
#  {'table_name': u'triggers'},
#  {'table_name': u'udt_privileges'},
#  {'table_name': u'role_udt_grants'},
#  {'table_name': u'usage_privileges'},
#  {'table_name': u'role_usage_grants'},
#  {'table_name': u'user_defined_types'},
#  {'table_name': u'view_column_usage'},
#  {'table_name': u'view_routine_usage'},
#  {'table_name': u'view_table_usage'},
#  {'table_name': u'views'},
#  {'table_name': u'data_type_privileges'},
#  {'table_name': u'element_types'},
#  {'table_name': u'column_options'},
#  {'table_name': u'foreign_data_wrapper_options'},
#  {'table_name': u'foreign_data_wrappers'},
#  {'table_name': u'foreign_server_options'},
#  {'table_name': u'foreign_servers'},
#  {'table_name': u'foreign_table_options'},
#  {'table_name': u'foreign_tables'},
#  {'table_name': u'user_mapping_options'},
#  {'table_name': u'user_mappings'},
#  {'table_name': u'pg_constraint'},
#  {'table_name': u'pg_index'},
#  {'table_name': u'pg_operator'},
#  {'table_name': u'pg_opfamily'},
#  {'table_name': u'pg_opclass'},
#  {'table_name': u'pg_am'},
#  {'table_name': u'avg_transformations'},
#  {'table_name': u'ophys_experiment_analysis_runs'},
#  {'table_name': u'executables'},
#  {'table_name': u'rgb_values'},
#  {'table_name': u'analysis_run_containers'},
#  {'table_name': u'rseq_experiment_components_star_analysis_runs'},
#  {'table_name': u'rseq_experiments'},
#  {'table_name': u'rseq_tube_inputs'},
#  {'table_name': u'rseq_tubes'},
#  {'table_name': u'cell_prep_samples_specimens'},
#  {'table_name': u'ephys_qc_criterias'},
#  {'table_name': u'refseq_human_gff_37'},
#  {'table_name': u'pg_depend'},
#  {'table_name': u'avg_graphic_objects'},
#  {'table_name': u'task_templates'},
#  {'table_name': u'sessions'},
#  {'table_name': u'loci'},
#  {'table_name': u'wij_sets'},
#  {'table_name': u'transcripts'},
#  {'table_name': u'flipped_specimens'},
#  {'table_name': u'image_structure_data'},
#  {'table_name': u'job_queue_notification_field_values'},
#  {'table_name': u'avg_microarray_templates'},
#  {'table_name': u'sub_images'},
#  {'table_name': u'job_queue_notifications_users'},
#  {'table_name': u'rseq_library_preps'},
#  {'table_name': u'cross_ontology_mappings'},
#  {'table_name': u'genes'},
#  {'table_name': u'sql_languages'},
#  {'table_name': u'sql_packages'},
#  {'table_name': u'sql_sizing'},
#  {'table_name': u'sql_sizing_profiles'},
#  {'table_name': u'differentiation_designs'},
#  {'table_name': u'differentiation_designs_differentiation_stages'},
#  {'table_name': u'annotated_region_histories'},
#  {'table_name': u'refseq_macaque_gff'},
#  {'table_name': u'ephys_roi_results'},
#  {'table_name': u'cell_prep_sample_types'},
#  {'table_name': u'well_known_file_types'},
#  {'table_name': u'genomic_reference_updates'},
#  {'table_name': u'wij_chunks'},
#  {'table_name': u'annovaluemaps'},
#  {'table_name': u'graph_views'},
#  {'table_name': u'handednesses'},
#  {'table_name': u'primers'},
#  {'table_name': u'annotationdetail'},
#  {'table_name': u'probe_expressed_states'},
#  {'table_name': u'orphanedannotationsets'},
#  {'table_name': u'equipment_runplans'},
#  {'table_name': u'postupdate'},
#  {'table_name': u'orphanedentities'},
#  {'table_name': u'differentiation_stage_instances'},
#  {'table_name': u'differentiation_sets'},
#  {'table_name': u'donors_genotypes'},
#  {'table_name': u'genotype_types'},
#  {'table_name': u'probe_alignments'},
#  {'table_name': u'planregionmaps'},
#  {'table_name': u'planregionmapcells'},
#  {'table_name': u'linkannotation'},
#  {'table_name': u'annotated_regions'},
#  {'table_name': u'refseq_mouse_gff'},
#  {'table_name': u'roi_exclusion_training_labels'},
#  {'table_name': u'runplan_states'},
#  {'table_name': u'analysis_runs_types'},
#  {'table_name': u'api_column_definitions'},
#  {'table_name': u'cell_roi_analysis_runs'},
#  {'table_name': u'roi_exclusion_labels'},
#  {'table_name': u'cell_rois_roi_exclusion_labels'},
#  {'table_name': u'cell_rois_roi_exclusion_training_labels'},
#  {'table_name': u'ercc_sets'},
#  {'table_name': u'project_sets_projects'},
#  {'table_name': u'reference3d_spaces'},
#  {'table_name': u'flat_field_correction_runs'},
#  {'table_name': u'organisms'},
#  {'table_name': u'project_sets'},
#  {'table_name': u'reference_to_reference_transforms'},
#  {'table_name': u'cell_prep_samples'},
#  {'table_name': u'specimen_blocks'},
#  {'table_name': u'specimen_hierarchies'},
#  {'table_name': u'bam_anonymization_runs'},
#  {'table_name': u'spatial_mappings'},
#  {'table_name': u'blast_versions'},
#  {'table_name': u'behavior_time_blocks'},
#  {'table_name': u'ext_genes_v'},
#  {'table_name': u'experiment_sessions'},
#  {'table_name': u'ext_genes_image_series_v'},
#  {'table_name': u'southern_blots'},
#  {'table_name': u'ext_image_series_treatments_v'},
#  {'table_name': u'refseq_human_gff'},
#  {'table_name': u'rseq_experiment_components'},
#  {'table_name': u'scheduled_procedures_subjects'},
#  {'table_name': u'tissue_processings'},
#  {'table_name': u'tasks_task_templates'},
#  {'table_name': u'cdna_primer_report_views'},
#  {'table_name': u'cel1_nucleases'},
#  {'table_name': u'affymetrix_probesets'},
#  {'table_name': u'cell_prep_roi_plans_cell_prep_templates'},
#  {'table_name': u'cell_additives'},
#  {'table_name': u'analysis_runs'},
#  {'table_name': u'job_queue_notifications'},
#  {'table_name': u'job_queue_notification_criterias_job_queue_notifications'},
#  {'table_name': u'job_queue_notifications_job_queues'},
#  {'table_name': u'graph_views_structures'},
#  {'table_name': u'calculatedilutions_v'},
#  {'table_name': u'job_queue_notification_reports_job_queue_notifications'},
#  {'table_name': u'polygon_spatial_mappings'},
#  {'table_name': u'methods_versions_watchers'},
#  {'table_name': u'methods_versions_task_templates'},
#  {'table_name': u'specimen_metadata'},
#  {'table_name': u'job_queue_notification_field_values_job_queue_notifications'},
#  {'table_name': u'injection_materials_surgical_procedures'},
#  {'table_name': u'surgical_procedures'},
#  {'table_name': u'hemispheres'},
#  {'table_name': u'color_channel_descriptions'},
#  {'table_name': u'methods_versions'},
#  {'table_name': u'cultured_cells'},
#  {'table_name': u'mouse_chrs_map'},
#  {'table_name': u'cell_preps_cell_prep_roi_plans'},
#  {'table_name': u'colors'},
#  {'table_name': u'log_messages'},
#  {'table_name': u'probe_refseq_blast_results'},
#  {'table_name': u'clone_primer_report_views'},
#  {'table_name': u'culture_conditions'},
#  {'table_name': u'methods_versions_ncrs'},
#  {'table_name': u'neuron_reconstruction_tags'},
#  {'table_name': u'operation_locations_operations'},
#  {'table_name': u'probe_pcr_products'},
#  {'table_name': u'cell_preps'},
#  {'table_name': u'macaque_chrs_map'},
#  {'table_name': u'ncbi_sequence_statuses'},
#  {'table_name': u'operations'},
#  {'table_name': u'reference_spaces'},
#  {'table_name': u'differentiation_stages_task_flows'},
#  {'table_name': u'facs'},
#  {'table_name': u'donor_dna_construct_types'},
#  {'table_name': u'ophys_cell_segmentation_runs'},
#  {'table_name': u'donor_dna_connections'},
#  {'table_name': u'ephys_neural_tissue_plans'},
#  {'table_name': u'facs_population_plans_facs'},
#  {'table_name': u'cell_rois'},
#  {'table_name': u'donor_dna_constructs_engineering_steps'},
#  {'table_name': u'injection_material_propagation_directions'},
#  {'table_name': u'ephys_roi_plans'},
#  {'table_name': u'donor_dna_construct_designs_donor_dna_promoters'},
#  {'table_name': u'differentiation_stages'},
#  {'table_name': u'engineering_drug_instances'},
#  {'table_name': u'ncrs_specimens'},
#  {'table_name': u'stem_cell_line_states'},
#  {'table_name': u'ephys_stimuli'},
#  {'table_name': u'specimen_types_specimens'},
#  {'table_name': u'specimen_sets_treatments'},
#  {'table_name': u'ephys_neural_tissue_plans_ephys_roi_plans'},
#  {'table_name': u'ephys_sweep_tags_ephys_sweeps'},
#  {'table_name': u'specimens_workflows'},
#  {'table_name': u'ephys_raw_stimulus_names'},
#  {'table_name': u'specimen_tags'},
#  {'table_name': u'executables_run_types'},
#  {'table_name': u'blocks'},
#  {'table_name': u'scheduled_procedure_notifications_users'},
#  {'table_name': u'blast_db_types'},
#  {'table_name': u'ext_genelookups_v'},
#  {'table_name': u'ephys_sweeps'},
#  {'table_name': u'primary_tissue_sources'},
#  {'table_name': u'executables_run_group_types'},
#  {'table_name': u'ercc_stock_pool_components'},
#  {'table_name': u'postmortem_intervals'},
#  {'table_name': u'executables_workflows'},
#  {'table_name': u'avg_group_labels'},
#  {'table_name': u'cell_prep_sample_collection_types'},
#  {'table_name': u'notification_types'},
#  {'table_name': u'ext_structures_v'},
#  {'table_name': u'specimens'},
#  {'table_name': u'facs_sops'},
#  {'table_name': u'flat_structures_v'},
#  {'table_name': u'notification_criteria_types'},
#  {'table_name': u'operation_types'},
#  {'table_name': u'scheduled_procedure_notification_date_ranges_scheduled_procedur'},
#  {'table_name': u'facs_population_plans'},
#  {'table_name': u'notification_run_frequencies'},
#  {'table_name': u'fine_structure_searches'},
#  {'table_name': u'ncrs'},
#  {'table_name': u'gene_tags_genes'},
#  {'table_name': u'isi_experiments'},
#  {'table_name': u'gene_classifications_genes'},
#  {'table_name': u'operation_locations'},
#  {'table_name': u'go_exons'},
#  {'table_name': u'occupations'},
#  {'table_name': u'assigned_users_scheduled_procedure_notifications'},
#  {'table_name': u'gene_termini'},
#  {'table_name': u'scheduled_procedure_notification_reports_scheduled_procedure_no'},
#  {'table_name': u'genomic_objects'},
#  {'table_name': u'notification_criterias'},
#  {'table_name': u'notification_reports'},
#  {'table_name': u'scheduled_procedure_notification_criterias_scheduled_procedure_'},
#  {'table_name': u'projects_scheduled_procedure_notifications'},
#  {'table_name': u'unit_of_times'},
#  {'table_name': u'injection_coordinates'},
#  {'table_name': u'scheduled_procedure_notifications'},
#  {'table_name': u'scheduled_procedure_notification_date_ranges'},
#  {'table_name': u'informatics_ranking_queries'},
#  {'table_name': u'injection_materials'},
#  {'table_name': u'unit_of_measurements'},
#  {'table_name': u'informatics_ranking_query_results'},
#  {'table_name': u'scheduled_procedure_notification_requested_date_ranges_schedule'},
#  {'table_name': u'facs_well_templates'},
#  {'table_name': u'job_transitions_scanners'},
#  {'table_name': u'donor_substances'},
#  {'table_name': u'homology_arms'},
#  {'table_name': u'job_transitions_workflows'},
#  {'table_name': u'equipment'},
#  {'table_name': u'job_transitions_run_group_types'},
#  {'table_name': u'substances'},
#  {'table_name': u'pcr_polymerases'},
#  {'table_name': u'ophys_experiment_tags'},
#  {'table_name': u'eye_trackings'},
#  {'table_name': u'ophys_sessions'},
#  {'table_name': u'imaging_depths'},
#  {'table_name': u'originating_labs'},
#  {'table_name': u'nuclease_activities_pcrs'},
#  {'table_name': u'probe_summary_views'},
#  {'table_name': u'projects_trigger_types'},
#  {'table_name': u'project_well_types'},
#  {'table_name': u'experiment_containers'},
#  {'table_name': u'reference_spaces_workflows'},
#  {'table_name': u'projection_structure_unionizes'},
#  {'table_name': u'probe_refseq_blast_results_v'},
#  {'table_name': u'related_jobs_v'},
#  {'table_name': u'rseq_library_quantification_methods'},
#  {'table_name': u'images'},
#  {'table_name': u'ophys_experiments'},
#  {'table_name': u'rseq_library_prep_sets'},
#  {'table_name': u'sections_slides_mappings'},
#  {'table_name': u'methods_versions_reviewers'},
#  {'table_name': u'sequencing_instruments'},
#  {'table_name': u'medical_condition_types'},
#  {'table_name': u'scheduled_procedures'},
#  {'table_name': u'methods_version_types'},
#  {'table_name': u'slide_registration_states'},
#  {'table_name': u'specimen_tags_specimens'},
#  {'table_name': u'stem_cell_line_sources'},
#  {'table_name': u'stem_cell_line_sources_stem_cell_lines'},
#  {'table_name': u'structure_sets'},
#  {'table_name': u'task_templates_surgical_procedures'},
#  {'table_name': u'talen_pairs'},
#  {'table_name': u'tcp_sops'},
#  {'table_name': u'task_flows'},
#  {'table_name': u'transfection_condition_colony_colors'},
#  {'table_name': u'trigger_types'},
#  {'table_name': u'user_header_elements'},
#  {'table_name': u'view_slide_parent_specimens'},
#  {'table_name': u'heatmap_runs'},
#  {'table_name': u'ephys_cell_plans'},
#  {'table_name': u'rseq_experiment_components_single_cell_analysis_runs'},
#  {'table_name': u'facs_facs_plate_templates'},
#  {'table_name': u'gene_associations'},
#  {'table_name': u'annotationset'},
#  {'table_name': u'classificationsynonym'},
#  {'table_name': u'allseries'},
#  {'table_name': u'structures'},
#  {'table_name': u'dataset'},
#  {'table_name': u'lims2imageseries'},
#  {'table_name': u'measuregroupvaluedefinition'},
#  {'table_name': u'point'},
#  {'table_name': u'class_mappings'},
#  {'table_name': u'clone_sources'},
#  {'table_name': u'clones'},
#  {'table_name': u'probe_fluor_combinations'},
#  {'table_name': u'probe_sets_run_groups'},
#  {'table_name': u'donors'},
#  {'table_name': u'ensembl_genes_v'},
#  {'table_name': u'ext_image_series_v'},
#  {'table_name': u'fluor_colors'},
#  {'table_name': u'freezers'},
#  {'table_name': u'ncbi_genes_v'},
#  {'table_name': u'refseq_human_gff_36'},
#  {'table_name': u'run_group_states'},
#  {'table_name': u'scanners'},
#  {'table_name': u'pg_event_trigger'},
#  {'table_name': u'users_work_groups'},
#  {'table_name': u'widgets'},
#  {'table_name': u'thicknesses'},
#  {'table_name': u'units'},
#  {'table_name': u'work_groups'},
#  {'table_name': u'view_calculate_dilutions'},
#  {'table_name': u'transfection_conditions'},
#  {'table_name': u'users'},
#  {'table_name': u'well_known_files'},
#  {'table_name': u'pg_attrdef'},
#  {'table_name': u'pg_amop'},
#  {'table_name': u'pg_amproc'},
#  {'table_name': u'pg_language'},
#  {'table_name': u'pg_aggregate'},
#  {'table_name': u'pg_rewrite'},
#  {'table_name': u'pg_trigger'},
#  {'table_name': u'treatment_tasks'},
#  {'table_name': u'pg_description'},
#  {'table_name': u'pg_cast'},
#  {'table_name': u'pg_enum'},
#  {'table_name': u'pg_namespace'},
#  {'table_name': u'pg_conversion'},
#  {'table_name': u'pg_database'},
#  {'table_name': u'pg_db_role_setting'},
#  {'table_name': u'pg_tablespace'},
#  {'table_name': u'pg_pltemplate'},
#  {'table_name': u'pg_auth_members'},
#  {'table_name': u'pg_shdepend'},
#  {'table_name': u'pg_shdescription'},
#  {'table_name': u'pg_ts_config'},
#  {'table_name': u'pg_ts_config_map'},
#  {'table_name': u'pg_ts_dict'},
#  {'table_name': u'pg_ts_parser'},
#  {'table_name': u'pg_ts_template'},
#  {'table_name': u'pg_extension'},
#  {'table_name': u'pg_foreign_data_wrapper'},
#  {'table_name': u'pg_foreign_server'},
#  {'table_name': u'pg_foreign_table'},
#  {'table_name': u'pg_default_acl'},
#  {'table_name': u'pg_seclabel'},
#  {'table_name': u'pg_shseclabel'},
#  {'table_name': u'pg_collation'},
#  {'table_name': u'pg_range'},
#  {'table_name': u'sql_implementation_info'},
#  {'table_name': u'pg_class'},
#  {'table_name': u'pg_inherits'},
#  {'table_name': u'sql_features'},
#  {'table_name': u'pg_largeobject_metadata'},
#  {'table_name': u'annotationplan'},
#  {'table_name': u'affymetrix_macaque_probesets'},
#  {'table_name': u'annotationplanreport'},
#  {'table_name': u'stringannotation'},
#  {'table_name': u'preupdate'},
#  {'table_name': u'postupdateall'},
#  {'table_name': u'preupdateall'},
#  {'table_name': u'activity_cells'},
#  {'table_name': u'affymetrix_transcript_clusters'},
#  {'table_name': u'targetentity'},
#  {'table_name': u'annotationplanuser'},
#  {'table_name': u'planregionmap'},
#  {'table_name': u'measuregroup'},
#  {'table_name': u'groupuser'},
#  {'table_name': u'reflabelupdates'},
#  {'table_name': u'array_slides'},
#  {'table_name': u'atlases'},
#  {'table_name': u'buffers'},
#  {'table_name': u'alignment3ds'},
#  {'table_name': u'atlases_avg_group_labels'},
#  {'table_name': u'alignment2ds'},
#  {'table_name': u'behavior_protocols'},
#  {'table_name': u'cell_descriptions'},
#  {'table_name': u'avg_replicate_types'},
#  {'table_name': u'behavior_trainings'},
#  {'table_name': u'cell_prep_roi_plans_chemicals'},
#  {'table_name': u'crisprs'},
#  {'table_name': u'blast_db_files'},
#  {'table_name': u'crisprs_nuclease_activities'},
#  {'table_name': u'probe_templates'},
#  {'table_name': u'custom_reports'},
#  {'table_name': u'sequences'},
#  {'table_name': u'chemicals'},
#  {'table_name': u'cell_bank_types'},
#  {'table_name': u'crisprs_engineering_steps'},
#  {'table_name': u'biocytin_wells'},
#  {'table_name': u'cell_prep_roi_plans'},
#  {'table_name': u'behavior_sessions'},
#  {'table_name': u'engineering_drugs'},
#  {'table_name': u'donor_dna_promoter_components'},
#  {'table_name': u'donor_dna_recombinases'},
#  {'table_name': u'entrez_aliases'},
#  {'table_name': u'ensembl_to_ncbi_mappings'},
#  {'table_name': u'donor_dna_elements'},
#  {'table_name': u'ephys_stimulus_set_groups'},
#  {'table_name': u'engineering_steps'},
#  {'table_name': u'ephys_specimen_roi_plans'},
#  {'table_name': u'donor_dna_recombinase_sites'},
#  {'table_name': u'cell_reporters'},
#  {'table_name': u'ephys_pipette_types'},
#  {'table_name': u'donor_dna_promoters_donor_dna_recombinase_sites'},
#  {'table_name': u'ephys_neural_tissue_templates_ephys_roi_plans'},
#  {'table_name': u'engineering_step_validations'},
#  {'table_name': u'ephys_sweep_tags'},
#  {'table_name': u'ercc_stock_pools'},
#  {'table_name': u'gene_classifications'},
#  {'table_name': u'facs_plate_templates'},
#  {'table_name': u'flips'},
#  {'table_name': u'genders'},
#  {'table_name': u'genome_loci'},
#  {'table_name': u'file_sources'},
#  {'table_name': u'genes_genotypes'},
#  {'table_name': u'go_files'},
#  {'table_name': u'external_controls'},
#  {'table_name': u'ercc_diluted_pools'},
#  {'table_name': u'facs_resources'},
#  {'table_name': u'go_file_types'},
#  {'table_name': u'header_elements'},
#  {'table_name': u'mechanical_dissociation_types'},
#  {'table_name': u'locations'},
#  {'table_name': u'injection_materials_injection_templates'},
#  {'table_name': u'ish_quality_metrics'},
#  {'table_name': u'informatics_ranking_query_types'},
#  {'table_name': u'human_chrs_map'},
#  {'table_name': u'injection_qualities'},
#  {'table_name': u'injection_materials_injections'},
#  {'table_name': u'nucleases'},
#  {'table_name': u'injections_structures'},
#  {'table_name': u'job_transitions_plane_of_sections'},
#  {'table_name': u'job_transitions_ages'},
#  {'table_name': u'list_configurations'},
#  {'table_name': u'microarray_chipsets'},
#  {'table_name': u'injections'},
#  {'table_name': u'pcrs'},
#  {'table_name': u'job_transitions_structures'},
#  {'table_name': u'pcr_names'},
#  {'table_name': u'neuronal_models'},
#  {'table_name': u'probe_types'},
#  {'table_name': u'registration_points'},
#  {'table_name': u'rna_amplifications'},
#  {'table_name': u'rs_alignment_runs'},
#  {'table_name': u'rs_tubesets'},
#  {'table_name': u'neuronal_model_template_types'},
#  {'table_name': u'plate_types'},
#  {'table_name': u'rs_tubes'},
#  {'table_name': u'rseq_oligos'},
#  {'table_name': u'probe_sources'},
#  {'table_name': u'rna_seq_experiments'},
#  {'table_name': u'neuronal_model_templates_well_known_files'},
#  {'table_name': u'nuclease_activities_talen_pairs'},
#  {'table_name': u'pcrs_southern_blots'},
#  {'table_name': u'reprogramming_methods'},
#  {'table_name': u'publishes'},
#  {'table_name': u'rna_amplification_sets'},
#  {'table_name': u'sub_image_annotation_tags'},
#  {'table_name': u'specimen_types'},
#  {'table_name': u'rseq_tube_sets'},
#  {'table_name': u'sub_image_annotations'},
#  {'table_name': u'stimulus_sets'},
#  {'table_name': u'rseq_size_selection_inputs'},
#  {'table_name': u'specimen_sets'},
#  {'table_name': u'stereotaxic_injections_structures'},
#  {'table_name': u'sub_image_annotation_tags_sub_image_annotations'},
#  {'table_name': u'structure_unionizes'},
#  {'table_name': u'rna_amplification_inputs'},
#  {'table_name': u'run_types'},
#  {'table_name': u'structure_sets_structures'},
#  {'table_name': u'sub_image_types'},
#  {'table_name': u'cell_banks'},
#  {'table_name': u'chemical_instances'},
#  {'table_name': u'donor_medical_conditions'},
#  {'table_name': u'talen_pairs_engineering_steps'},
#  {'table_name': u'tissuecyte_calibrations'},
#  {'table_name': u'transfection_methods'},
#  {'table_name': u'transgenic_line_sources'},
#  {'table_name': u'wash_buffer_types'},
#  {'table_name': u'well_types'},
#  {'table_name': u'plates'},
#  {'table_name': u'tumor_features'},
#  {'table_name': u'transgenic_induction_methods'},
#  {'table_name': u'washes'},
#  {'table_name': u'top_levels'},
#  {'table_name': u'workflows'},
#  {'table_name': u'talens'},
#  {'table_name': u'cell_prep_specimen_roi_plans'},
#  {'table_name': u'donor_dna_construct_designs'},
#  {'table_name': u'neuron_reconstruction_tags_neuron_reconstructions'},
#  {'table_name': u'reference_genomes'},
#  {'table_name': u'stem_cell_lines'},
#  {'table_name': u'executables_projects'},
#  {'table_name': u'annotationuser'},
#  {'table_name': u'annotationgroup'},
#  {'table_name': u'classificationitem'},
#  {'table_name': u'annotatedvaluedefinition'},
#  {'table_name': u'annotationproject'},
#  {'table_name': u'classificationitemretired'},
#  {'table_name': u'region'},
#  {'table_name': u'targetentitytype'},
#  {'table_name': u'annotationspace'},
#  {'table_name': u'wells'},
#  {'table_name': u'genomicspreadsheet'},
#  {'table_name': u'allseries4_6'},
#  {'table_name': u'classificationannotation'},
#  {'table_name': u'allseries4_6_2'},
#  {'table_name': u'floatannotation'},
#  {'table_name': u'annotationitem'},
#  {'table_name': u'annotationsetupdates'},
#  {'table_name': u'integerannotation'},
#  {'table_name': u'annotationitemupdates'},
#  {'table_name': u'annotationprojectuser'},
#  {'table_name': u'planregionmapcell'},
#  {'table_name': u'correcttargetentityvalues'},
#  {'table_name': u'groupgroup'},
#  {'table_name': u'regionregion'},
#  {'table_name': u'revisionhistory'},
#  {'table_name': u'ages_executables'},
#  {'table_name': u'archives'},
#  {'table_name': u'death_causes'},
#  {'table_name': u'blocks_section_arrangements'},
#  {'table_name': u'run_groups'},
#  {'table_name': u'chromosomes'},
#  {'table_name': u'vertexset'},
#  {'table_name': u'imageseriesgene'},
#  {'table_name': u'probe_template_batches'},
#  {'table_name': u'slides'},
#  {'table_name': u'access_rights'},
#  {'table_name': u'avg_replicates'},
#  {'table_name': u'cell_prep_tubes'},
#  {'table_name': u'blast_runs'},
#  {'table_name': u'cell_soma_locations'},
#  {'table_name': u'audits'},
#  {'table_name': u'calculatedilutiontemplate'},
#  {'table_name': u'ages_job_transitions'},
#  {'table_name': u'death_manners'},
#  {'table_name': u'cloning_vectors'},
#  {'table_name': u'probes'},
#  {'table_name': u'runplans'},
#  {'table_name': u'transcript_versions'},
#  {'table_name': u'ages'},
#  {'table_name': u'differentiations'},
#  {'table_name': u'donor_dna_promoters'},
#  {'table_name': u'down_sample_job_details'},
#  {'table_name': u'drugs'},
#  {'table_name': u'equalizations'},
#  {'table_name': u'run_group_types'},
#  {'table_name': u'erccs'},
#  {'table_name': u'engineering_steps_helper_plasmids'},
#  {'table_name': u'gene_symbol_aliases'},
#  {'table_name': u'engineering_step_component_assemblies'},
#  {'table_name': u'image_series'},
#  {'table_name': u'treatments'},
#  {'table_name': u'plane_of_sections'},
#  {'table_name': u'runplans_treatments'},
#  {'table_name': u'equipment_classes'},
#  {'table_name': u'executables_treatments'},
#  {'table_name': u'ephys_stimulus_types'},
#  {'table_name': u'homologene_groups'},
#  {'table_name': u'donor_dna_constructs'},
#  {'table_name': u'donor_dna_recombinases_engineering_steps'},
#  {'table_name': u'drug_instances'},
#  {'table_name': u'education_levels'},
#  {'table_name': u'engineering_step_component_designs'},
#  {'table_name': u'molbio_authorities'},
#  {'table_name': u'projects'},
#  {'table_name': u'genotypes'},
#  {'table_name': u'gene_classification_uses'},
#  {'table_name': u'file_uploads'},
#  {'table_name': u'go_files_specimens'},
#  {'table_name': u'gene_classification_categories'},
#  {'table_name': u'frozen_media'},
#  {'table_name': u'isi_experiment_tags'},
#  {'table_name': u'helper_plasmids'},
#  {'table_name': u'neuronal_model_runs'},
#  {'table_name': u'image_series_image_series_tags'},
#  {'table_name': u'job_transitions_orientations'},
#  {'table_name': u'job_transitions_treatments'},
#  {'table_name': u'medical_conditions'},
#  {'table_name': u'image_series_slides'},
#  {'table_name': u'image_types'},
#  {'table_name': u'isi_experiment_tags_isi_experiments'},
#  {'table_name': u'job_queues'},
#  {'table_name': u'neuron_reconstructions'},
#  {'table_name': u'gene_association_sources'},
#  {'table_name': u'gene_histories'},
#  {'table_name': u'job_transitions'},
#  {'table_name': u'gene_tags'},
#  {'table_name': u'heatmap_types'},
#  {'table_name': u'image_series_tags'},
#  {'table_name': u'job_transitions_projects'},
#  {'table_name': u'jobs'},
#  {'table_name': u'ldds'},
#  {'table_name': u'rna_amplification_methods'},
#  {'table_name': u'scans'},
#  {'table_name': u'ontologies'},
#  {'table_name': u'schema_migrations'},
#  {'table_name': u'rseq_size_selections'},
#  {'table_name': u'restriction_enzymes_southern_blots'},
#  {'table_name': u'slide_groups'},
#  {'table_name': u'section_arrangements'},
#  {'table_name': u'sections'},
#  {'table_name': u'rseq_size_selection_sets'},
#  {'table_name': u'nuclease_activities'},
#  {'table_name': u'resolutions'},
#  {'table_name': u'probe_template_types'},
#  {'table_name': u'probe_results'},
#  {'table_name': u'probe_sets'},
#  {'table_name': u'restriction_enzymes'},
#  {'table_name': u'plate_usages'},
#  {'table_name': u'pcr_reaction_types'},
#  {'table_name': u'neuronal_model_templates'},
#  {'table_name': u'ophys_experiment_tags_ophys_experiments'},
#  {'table_name': u'pcr_products'},
#  {'table_name': u'orientations'},
#  {'table_name': u'pcr_confirmation_sequencing_runs'},
#  {'table_name': u'rna_to_map_well_mappings'},
#  {'table_name': u'normalization_groups'},
#  {'table_name': u'cell_samples'},
#  {'table_name': u'system_settings'},
#  {'table_name': u'races'},
#  {'table_name': u'sequence_types'},
#  {'table_name': u'gene_classification_sources'},
#  {'table_name': u'structure_graphs'},
#  {'table_name': u'stimulus_sets_well_known_files'},
#  {'table_name': u'blast_alignments'},
#  {'table_name': u'surgery_orientations'},
#  {'table_name': u'annotationplanvaluedefinition'},
#  {'table_name': u'southern_blot_label_types'},
#  {'table_name': u'specimen_preparation_methods'},
#  {'table_name': u'slide_tags'},
#  {'table_name': u'sub_image_qcstate_reasons'},
#  {'table_name': u'template_tags'},
#  {'table_name': u'refseq_homologenes'},
#  {'table_name': u'task_flow_steps_task_templates'},
#  {'table_name': u'rseq_library_prep_methods'},
#  {'table_name': u'biospecimen_polygons'},
#  {'table_name': u'ephys_features'},
#  {'table_name': u'differentiation_collection_days'},
#  {'table_name': u'task_flow_steps'},
#  {'table_name': u'rna_seq_analysis_runs_rna_seq_experiments'},
#  {'table_name': u'facs_specimens'},
#  {'table_name': u'job_states'},
#  {'table_name': u'primer_reports'},
#  {'table_name': u'slide_tags_slides'},
#  {'table_name': u'source_roles'},
#  {'table_name': u'structure_edges'}]

# %%
my_query = "SELECT * FROM specimens LIMIT 10"
my_result = limsquery(my_query)
first_element = my_result[0]
print sorted(first_element.keys())
# Out:
# ['alignment3d_id', 'barcode', 'biophysical_model_state', 'carousel_well_name', 'cell_depth', 'cell_label', 'cell_prep_id', 'cell_reporter_id', 'cortex_layer_id', 'created_at', 'created_by', 'data', 'donor_id', 'ephys_cell_plan_id', 'ephys_neural_tissue_plan_id', 'ephys_qc_result', 'ephys_roi_result_id', 'ephys_start_time_sec', 'external_specimen_name', 'facs_well_id', 'flipped_specimen_id', 'frozen_at', 'hemisphere_id', 'histology_well_name', 'id', 'location_id', 'name', 'normalization_group_id', 'operation_id', 'parent_id', 'parent_x_coord', 'parent_y_coord', 'parent_z_coord', 'patched_cell_container', 'pinned_radius', 'plane_of_section_id', 'postmortem_interval_id', 'preparation_method_id', 'priority', 'project_id', 'reference_space_id', 'rna_integrity_number', 'specimen_preparation_method_id', 'specimen_set_id', 'storage_directory', 'structure_id', 'task_flow_id', 'tissue_ph', 'tissue_processing_id', 'updated_at', 'updated_by', 'x_coord', 'y_coord']

# %%
my_query = "SELECT * FROM well_known_files LIMIT 10"
my_result = limsquery(my_query)
first_element = my_result[0]
print first_element.keys()
# Out:
# ['published_at', 'workflow_state', 'created_at', 'updated_at', 'filename', 'storage_directory', 'file_source_id', 'attachable_type', 'content_type', 'well_known_file_type_id', 'attachable_id', 'id', 'size']

# %% [markdown]
# ### This will be easiest to use if we stick it in a dataframe

# %%
#more code written by Agata

def get_lims_dataframe(query):
    '''Return a dataframe with lims query'''
    result = limsquery(query)
    try:
        data_df = pd.DataFrame(data=result, columns=result[0].keys())
    except IndexError:
        print "Could not find results for your query."
        data_df = pd.DataFrame()
    return data_df

# %% [markdown]
# This is the basics of how a SQL query looks
#
# SELECT TableA.*, TableB.*, TableC.*, TableD.*
# FROM TableA
#     JOIN TableB
#         ON TableB.aID = TableA.aID
#     JOIN TableC
#         ON TableC.cID = TableB.cID
# WHERE DATE(TableC.date)=date(now())
#
# This allows us to pull in info from 4 different tables since everything we want is not stored in one place, but there are overlaps to link things up. 10 digit IDs generally are your link

# %% [markdown]
# ### We can shorten ephys_roi_results to err and specimens to s, search for all of our features and use <br>JOIN to join the search results from ephys_roi_results and specimens following the outline from above

# %%
lims_query = "SELECT err.id, err.recording_date, err.failed_bad_rs, \
err.failed_electrode_0, err.failed_clogged_pipette, err.failed_no_seal, \
err.failed_other, err.workflow_state, s.name, s.ephys_roi_result_id, s.project_id, proj.id, proj.code, \
f.storage_directory, f.attachable_id \
FROM ephys_roi_results err JOIN specimens s ON s.ephys_roi_result_id = err.id \
JOIN projects proj ON s.project_id = proj.id \
JOIN well_known_files f ON err.id = f.attachable_id \
WHERE (failed_bad_rs = 'TRUE' \
AND err.failed_electrode_0 = 'FALSE' \
AND err.failed_clogged_pipette = 'FALSE' \
AND err.failed_no_seal = 'FALSE' \
AND err.failed_other = 'FALSE' \
AND err.workflow_state != 'manual_passed') \
AND (proj.code = 'T301' OR proj.code = 'T301x') \
AND f.filename LIKE '%%ephys_features.json'"

lims_df = get_lims_dataframe(lims_query)
lims_df.tail()
# Out:
#     ephys_roi_result_id  code      recording_date failed_bad_rs  \
# 40            579497253  T301 2017-04-04 15:22:26          True
# 41            579645792  T301 2017-04-05 12:56:54          True
# 42            580812829  T301 2017-04-11 09:44:52          True
# 43            580900050  T301 2017-04-11 14:44:26          True
# 44            580901813  T301 2017-04-11 15:21:05          True
#
#    workflow_state                                               name  \
# 40  manual_failed               Vipr2-IRES2-Cre;Ai14-310516.06.02.01
# 41  manual_failed              Ndnf-IRES2-dgCre;Ai14-311164.05.02.01
# 42  manual_failed        Nkx2-1-CreERT2;Ai14 (IVSCC)-311670.04.02.01
# 43  manual_failed  Chrna2-Cre_OE25;Pvalb-T2A-Dre;Ai66-309757.05.0...
# 44  manual_failed  Chrna2-Cre_OE25;Pvalb-T2A-Dre;Ai66-309757.05.0...
#
#     attachable_id failed_clogged_pipette  \
# 40      579497253                  False
# 41      579645792                  False
# 42      580812829                  False
# 43      580900050                  False
# 44      580901813                  False
#
#                                     storage_directory failed_other  \
# 40  /projects/mousecelltypes/vol1/prod997/Ephys_Ro...        False
# 41  /projects/mousecelltypes/vol1/prod997/Ephys_Ro...        False
# 42  /projects/mousecelltypes/vol1/prod1002/Ephys_R...        False
# 43  /projects/mousecelltypes/vol1/prod1003/Ephys_R...        False
# 44  /projects/mousecelltypes/vol1/prod1003/Ephys_R...        False
#
#     project_id failed_electrode_0         id failed_no_seal
# 40   305094322              False  305094322          False
# 41   305094322              False  305094322          False
# 42   305094322              False  305094322          False
# 43   305094322              False  305094322          False
# 44   305094322              False  305094322          False

# %% [markdown]
# ## Searching for the features json seems to limit us in our search so lets remove that

# %%
lims_query = "SELECT err.id, err.recording_date, err.failed_bad_rs, \
err.failed_electrode_0, err.failed_clogged_pipette, err.failed_no_seal, \
err.failed_other, err.workflow_state, s.name, s.ephys_roi_result_id, s.project_id, proj.id, proj.code \
FROM ephys_roi_results err JOIN specimens s ON s.ephys_roi_result_id = err.id \
JOIN projects proj ON s.project_id = proj.id \
WHERE (failed_bad_rs = 'TRUE' \
AND err.failed_electrode_0 = 'FALSE' \
AND err.failed_clogged_pipette = 'FALSE' \
AND err.failed_no_seal = 'FALSE' \
AND err.failed_other = 'FALSE' \
AND err.workflow_state != 'manual_passed') \
AND (proj.code = 'T301' OR proj.code = 'T301x')"

lims_df = get_lims_dataframe(lims_query)
lims_df.tail()
# Out:
#     ephys_roi_result_id   code      recording_date failed_bad_rs  \
# 67            601831626   T301 2017-07-10 21:03:11          True
# 68            602660919   T301 2017-07-13 22:16:27          True
# 69            604693290  T301x 2017-07-26 22:50:46          True
# 70            605537141  T301x 2017-07-28 20:37:50          True
# 71            605538385  T301x 2017-07-28 21:32:11          True
#
#    workflow_state                                 name failed_clogged_pipette  \
# 67  manual_failed    Nos1-CreERT2;Ai14-333287.03.01.01                  False
# 68  manual_failed  Scnn1a-Tg2-Cre;Ai14-333165.04.02.01                  False
# 69  manual_failed  Rbp4-Cre_KL100;Ai14-337193.04.02.01                  False
# 70  manual_failed   Gad2-IRES-Cre;Ai14-336420.04.02.01                  False
# 71  manual_failed   Gad2-IRES-Cre;Ai14-336420.02.02.01                  False
#
#    failed_other  project_id failed_electrode_0         id failed_no_seal
# 67        False   305094322              False  305094322          False
# 68        False   305094322              False  305094322          False
# 69        False   300080300              False  300080300          False
# 70        False   300080300              False  300080300          False
# 71        False   300080300              False  300080300          False

# %% [markdown]
# # The donors table didn't seem to be helpful in giving us the genotype so <br>let's just strip the labtracks.id off of names and use the count function in pandas

# %%
lims_df['genotype'] = lims_df['name'].apply(lambda x: x[:-16])
lims_df.groupby(['genotype']).size()
# Out:
# genotype
# Chat-IRES-Cre-neo;Ai14                 5
# Chrna2-Cre_OE25;Ai14(IVSCC)            1
# Chrna2-Cre_OE25;Pvalb-T2A-Dre;Ai66     2
# Esr2-IRES2-Cre;Ai14                    1
# Htr3a-Cre_NO152;Ai14                   1
# Ndnf-IRES2-dgCre;Ai14                  3
# Nkx2-1-CreERT2;Ai14 (IVSCC)            5
# Nos1-CreERT2;Ai14                      1
# Nos1-CreERT2;Sst-IRES-FlpO;Ai65        2
# Oxtr-T2A-Cre;Ai14                      1
# Pvalb-IRES-Cre;Ai14                   11
# Scnn1a-Tg3-Cre;Ai14                    1
# Sst-IRES-Cre;Ai14                      1
# Vip-IRES-Cre;Ai14                      6
# Vip-IRES-Cre;Ai14(IVSCC)               1
# Vipr2-IRES2-Cre;Ai14                   3
# dtype: int64

# %% [markdown]
# # Quick practice on finding another dataset in LIMS

# %%
lims_query = "SELECT err.id, err.recording_date, s.name, s.ephys_roi_result_id, proj.code \
FROM ephys_roi_results err JOIN specimens s ON s.ephys_roi_result_id = err.id \
JOIN projects proj ON s.project_id = proj.id \
AND proj.code = 'mMPATCH'"
lims_df = get_lims_dataframe(lims_query)
lims_df.tail()
# Out:
#     ephys_roi_result_id     code         id recording_date  \
# 14            645416634  mMPATCH  645416634           None
# 15            645416707  mMPATCH  645416707           None
# 16            645416721  mMPATCH  645416721           None
# 17            645416770  mMPATCH  645416770           None
# 18            645416815  mMPATCH  645416815           None
#
#                                                  name
# 14  Tlx3-Cre_PL56;Ai140;Sst-IRES-FlpO;Ai65F-354156...
# 15  Sst-IRES-Cre;Ai140;Pvalb-2A-FlpO;Ai65F-352872....
# 16  Vip-IRES-Cre;Ai140;Pvalb-T2A-FlpO;Ai65F-353601...
# 17  Sst-IRES-Cre;Ai140;Pvalb-2A-FlpO;Ai65F-351634....
# 18  Vip-IRES-Cre;Ai140;Pvalb-T2A-FlpO;Ai65F-351614...

# %%
my_query = "SELECT * FROM rna_amplifications LIMIT 10"
my_result = limsquery(my_query)
first_element = my_result[0]
print first_element.keys()
# Out:
# ['umi_length_nt', 'amplified_quantity_ng', 'name', 'run_date', 'percent_cdna_longer_than_400bp', 'created_at', 'updated_at', 'failed', 'ercc_diluted_pool_id', 'ercc_pool_ul', 'rna_amplification_method_id', 'cycles', 'id', 'rna_amplification_set_id']

# %%
my_query = "SELECT ra.amplified_quantity_ng, ra.name, ra.run_date, ra.percent_cdna_longer_than_400bp, ra.failed, \
ra.cycles, ra.id, rai.sample_id, cell.id, cell.name, cell.created_at, cell.patched_cell_container \
FROM specimens cell \
LEFT JOIN rna_amplification_inputs rai ON rai.sample_id = cell.id \
LEFT JOIN rna_amplifications ra ON ra.id = rai.rna_amplification_id \
WHERE run_date > '2017-01-01'"
my_result = limsquery(my_query)
first_element = my_result[0]
data_df = pd.DataFrame(data=my_result, columns=my_result[0].keys())
data_df.head()
# Out:
#    amplified_quantity_ng                 name            run_date  \
# 0                 0.0000  H16.06.012.11.03.01 2017-01-04 08:00:00
# 1                 1.1048  H16.06.012.11.03.02 2017-01-04 08:00:00
# 2                 0.3869  H16.06.012.11.03.03 2017-01-04 08:00:00
# 3                 0.5355  H16.06.012.11.03.04 2017-01-04 08:00:00
# 4                 0.5713  H16.06.012.11.03.05 2017-01-04 08:00:00
#
#    percent_cdna_longer_than_400bp                 created_at failed  \
# 0                        0.000000 2016-09-29 21:13:38.114713   True
# 1                       67.414917 2016-09-29 21:38:34.754088  False
# 2                       37.167227 2016-09-29 22:29:08.487196   True
# 3                       42.166200 2016-09-29 22:48:46.884752  False
# 4                       40.994224 2016-09-29 23:09:13.059575   True
#
#   patched_cell_container  sample_id  cycles         id
# 0    P1S4_160929_003_A01  548408304      19  548408304
# 1    P1S4_160929_004_A01  548417970      19  548417970
# 2    P1S4_160929_005_A01  548436554      19  548436554
# 3    P1S4_160929_006_A01  548444214      19  548444214
# 4    P1S4_160929_007_A01  548452482      19  548452482

# %%
len(data_df[data_df['failed'] == False])
# Out:
# 2286

# %%
data_df.cycles.unique()
# Out:
# array([19, 18, 21], dtype=int64)

# %%
data_df[data_df['cycles'] == 21]['created_at'].min()
# Out:
# Timestamp('2017-04-21 17:58:36.870815')

# %%
shiny.head()
# Out:
#             Unnamed: 0             cl  score  marker.num  resolution.index  \
# 0  P6S4_170808_252_A01          Meis2   0.99          19               1.0
# 1  P2S4_170301_057_A01  Lamp5 Rgs12_3   1.00          26               1.0
# 2  P1S4_160406_097_A01  Lamp5 Rgs12_3   0.93          18               1.0
# 3  P2S4_170310_057_A01  Lamp5 Rgs12_3   0.83          19               1.0
# 4  P2S4_170922_055_A01  Lamp5 Rgs12_3   0.81          22               1.0
#
#    h.score                                            markers  \
# 0     0.99  Meis2:Meis2 Scgn Amigo2 Filip1l Grm2 Lgr6 G630...
# 1     1.00  Lamp5 Rgs12_3:Sema3e Tnnt1 Ntn1 Rxfp1 Fam19a2 ...
# 2     0.93  Lamp5 Rgs12_3:Sema3e Tnnt1 Rxfp1 Ptprt LOC1010...
# 3     0.83  Lamp5 Rgs12_3:Sema3e Tnnt1 Rxfp1 Ptprt Gria1 L...
# 4     0.81  Lamp5 Rgs12_3:Sema3e Tnnt1 Rxfp1 Fam19a2 Gria1...
#
#    resolution.index.percentile  \
# 0                          100
# 1                          100
# 2                          100
# 3                          100
# 4                          100
#
#                                   exp_component_name      ar_id     ...       \
# 0                                   PS0907_E1-50_S34  623358639     ...
# 1                              msPSX170321_E1_50_S11  578474417     ...
# 2  PSX160502_E1_50_S8_and_PSX160502_E2_50_S8_and_...  523786138     ...
# 3                              msPSX170321_E1_50_S49  578474341     ...
# 4                                SM-GE63O_S009_E1-50  645671846     ...
#
#           Post_Patch Total_time Ephys_time Retraction_time  Fill.Date  \
# 0                  0        NaN        NaN             NaN        NaN
# 1                  0        NaN        NaN             NaN        NaN
# 2  partial nucleated        NaN        NaN             NaN        NaN
# 3                  0        NaN        NaN             NaN        NaN
# 4    nucleus_present        NaN       34.0             NaN  8/31/2017
#
#    Rig_Operator  Rig_number  retraction_pressure  pilot_name End_pipetteR
# 0           NaN         NaN                  NaN         NaN          NaN
# 1           NaN         NaN                  NaN         NaN          NaN
# 2           NaN         NaN                  NaN         NaN          NaN
# 3           NaN         NaN                  NaN         NaN          NaN
# 4        rustym           6                -30.0         NaN          NaN
#
# [5 rows x 112 columns]

# %%
shiny = pd.read_csv('\\\\allen\\programs\\celltypes\\workgroups\\rnaseqanalysis\\shiny\\patch_seq\\mouse_patchseq_VISp_20171204_collapsed90\\mapping.df.with.bp.90.csv')

# %%
df_new = pd.merge(data_df, shiny, left_on = 'patched_cell_container', right_on = 'Unnamed: 0')

# %%
df_new[df_new['Retraction_time'].notnull()]
# Out:
#       amplified_quantity_ng_x  \
# 1094                 2.548507
# 1095                 5.740796
# 1096                15.401426
# 1097                11.077913
# 1101                12.071228
# 1102                20.745630
# 1103                11.645717
# 1104                 6.906475
# 1106                11.125648
# 1107                 3.784308
# 1108                 3.642626
# 1109                 3.447394
# 1110                 4.673653
# 1111                 5.488300
# 1112                 6.248477
# 1113                 5.656204
# 1114                 9.704651
# 1115                 9.713137
# 1116                13.832545
# 1117                 4.659098
# 1118                12.997367
# 1119                14.454628
# 1121   nucleus_absent      502.0        33.0            243.0  9/25/2017
# 1122  nucleus_present      534.0        28.0            142.0  9/25/2017
# 1123  nucleus_present      417.0        35.0            130.0  9/25/2017
# 1124  nucleus_present      669.0        46.0            140.0  9/25/2017
# 1125   nucleus_absent      776.0        36.0            261.0  9/25/2017
# 1126  nucleus_present      588.0        22.0            147.0  9/25/2017
# 1127  nucleus_present      606.0        22.0            158.0  9/25/2017
# ...               ...        ...         ...              ...        ...
# 1325  nucleus_present      668.0        16.0            142.0  9/25/2017
# 1326  nucleus_present      588.0        22.0            147.0  9/25/2017
# 1327  nucleus_present      455.0        29.0            149.0  9/25/2017
# 1328  nucleus_present      337.0        22.0            120.0  9/25/2017
# 1329   nucleus_absent      407.0        22.0            169.0  9/25/2017
# 1330  nucleus_present      626.0        61.0            108.0  9/25/2017
# 1331  nucleus_present      578.0        29.0            108.0  9/25/2017
# 1332  nucleus_present      389.0        23.0            119.0  9/25/2017
# 1333  nucleus_present      480.0        18.0            121.0  9/25/2017
# 1334  nucleus_present      584.0        28.0            155.0  9/25/2017
# 1335  nucleus_present      537.0        41.0             66.0  9/25/2017
# 1336  nucleus_present      741.0        51.0             73.0  9/25/2017
# 1337  nucleus_present      691.0        22.0            143.0  9/25/2017
# 1338   nucleus_absent      321.0       299.0             34.0  9/25/2017
# 1339   nucleus_absent      677.0        25.0            113.0  9/25/2017
# 1340   nucleus_absent      791.0        36.0            314.0  9/25/2017
# 1341   nucleus_absent      708.0        66.0             52.0  9/25/2017
# 1342   nucleus_absent      569.0        20.0            195.0  9/25/2017
# 1343   nucleus_absent      643.0        12.0            176.0  9/25/2017
# 1344  nucleus_present      925.0       261.0              8.0  9/25/2017
# 1345  nucleus_present      859.0       349.0              1.0  9/25/2017
# 1350  nucleus_present      902.0        89.0            156.0  9/25/2017
# 1351   nucleus_absent      668.0        46.0            330.0  9/25/2017
# 1352  nucleus_present      472.0        49.0            131.0  9/25/2017
# 1353  nucleus_present      460.0        31.0            115.0  9/25/2017
# 1354   nucleus_absent      733.0        37.0            400.0  9/25/2017
# 1355  nucleus_present      636.0        41.0            112.0  9/25/2017
# 1356  nucleus_present      475.0        19.0            133.0  9/25/2017
# 1357   nucleus_absent      673.0        39.0            261.0  9/25/2017
# 1358   nucleus_absent      922.0        48.0            411.0  9/25/2017
#
#       Rig_Operator Rig_number  retraction_pressure  \
# 1094        rustym          5                -32.5
# 1095        rustym          5                -30.0
# 1096        rustym          5                -32.0
# 1097        rustym          5                -35.0
# 1101      lindsayn          7                -30.0
# 1102      lindsayn          7                -30.0
# 1103      lindsayn          7                -30.0
# 1104      lindsayn          7                -30.0
# 1106         lisak          6                -23.9
# 1107         lisak          6                -23.2
# 1108         lisak          6                -26.6
# 1109         lisak          6                -26.6
# 1110         lisak          6                -30.0
# 1111          ramr          4                -35.0
# 1112        rustym          5                -26.0
# 1113        rustym          5                -50.0
# 1114        rustym          5                -51.0
# 1115        rustym          5                -30.0
# 1116        rustym          5                -35.0
# 1117        rustym          5                -25.0
# 1118        rustym          5                -30.0
# 1119        rustym          5                -30.0
# 1120        rustym          5                -40.0
# 1121        rustym          5                -35.0
# 1122        rustym          5                -30.0
# 1123        rustym          5                -30.0
# 1124      lindsayn          7                -30.0
# 1125      lindsayn          7                -30.0
# 1126      lindsayn          7                -25.0
# 1127      lindsayn          7                -28.0
# ...            ...        ...                  ...
# 1325         lisak          6                -24.7
# 1326      lindsayn          7                -25.0
# 1327         lisak          6                -23.6
# 1328         lisak          6                -23.9
# 1329        rustym          5                -30.0
# 1330      lindsayn          7                -38.0
# 1331          ramr          4                -39.0
# 1332         lisak          6                -23.6
# 1333      lindsayn          7                -25.0
# 1334      lindsayn          7                -25.0
# 1335        dijonh          3                -30.0
# 1336        dijonh          3                -40.0
# 1337          ramr          4                -34.0
# 1338          ramr          4                  NaN
# 1339      lindsayn          7                -30.0
# 1340      lindsayn          7                -30.0
# 1341        dijonh          3                -43.0
# 1342          ramr          4                -24.0
# 1343      lindsayn          7                -25.0
# 1344        briank       HCT2                 90.0
# 1345        briank       HCT2                 90.0
# 1350      lindsayn          3                -70.0
# 1351        rustym          5                -50.0
# 1352        rustym          5                -51.0
# 1353        rustym          5                -26.0
# 1354        rustym          5                -30.0
# 1355        dijonh          3                -25.0
# 1356         lisak          6                -23.2
# 1357         lisak          6                -22.6
# 1358      lindsayn          7                -30.0
#
#                                  pilot_name  End_pipetteR
# 1094  Nucleated Patch - Retraction Pressure            10
# 1095  Nucleated Patch - Retraction Pressure          1000
# 1096  Nucleated Patch - Retraction Pressure          1000
# 1097                                   None            40
# 1101                                   None          1100
# 1102                                   None          1400
# 1103                                   None          3000
# 1104                                   None            30
# 1106                                   None          1000
# 1107                                   None          1000
# 1108                                   None           930
# 1109                                   None           4.7
# 1110                                   None          16.2
# 1111                                   None          10.2
# 1112                                   None          1000
# 1113                                   None            10
# 1114                                   None          1000
# 1115                                   None            10
# 1116                                   None          1000
# 1117                                   None            20
# 1118                                   None          1000
# 1119                                   None          1000
# 1120                                   None          1000
# 1121                                   None            10
# 1122                                   None          1000
# 1123                                   None          1000
# 1124                                   None          2300
# 1125                                   None           150
# 1126                                   None          2500
# 1127                                   None          1700
# ...                                     ...           ...
# 1325                                   None           600
# 1326                                   None          2500
# 1327                                   None          1800
# 1328                                   None          2500
# 1329                                   None            10
# 1330                                   None          2000
# 1331                                   None          3000
# 1332                                   None          1700
# 1333                                   None          1200
# 1334                                   None           150
# 1335                                   None           300
# 1336                                   None          1000
# 1337                                   None          3000
# 1338                           Tissue_Touch            20
# 1339                                   None          3000
# 1340                                   None           200
# 1341                                   None           400
# 1342                                   None           4.6
# 1343                                   None           200
# 1344                                   None          1400
# 1345                                   None          1500
# 1350                                   None          2000
# 1351                                   None            10
# 1352                                   None          1000
# 1353                                   None          1000
# 1354                                   None            10
# 1355                                   None           300
# 1356                                   None          2000
# 1357                                   None           250
# 1358                                   None           150
#
# [256 rows x 122 columns]
